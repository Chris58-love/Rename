# %% [markdown]
# # Universal Rename Tool - Colab Launcher

# %%
# If running from a cloned repository, execute this cell inside the project directory.
# !pip install -r requirements.txt

# %%
from universal_rename_tool.ui_colab import launch_colab_app
launch_colab_app()
